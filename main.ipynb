# %%
pip install tensorflow matplotlib scikit-learn numpy pandas
# Out:
# ...
#      |████████████████████████████████| 229.6 MB 61 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 7.6 MB 69.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.2 MB 30.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.6 MB 41.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 11.8 MB 132.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 393 kB 25.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.7 MB 84.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 9.6 MB 74.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.2 MB 30.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.5 MB 116.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 23.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.7 MB 83.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 110.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 130 kB 20.3 MB/s eta 0:00:01
# ...
